# %% [markdown]
# Import numpy and pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# Using the bash magic command, view the list of files inside of the data directory.

# %%
# %pwd
# %cd data
# %pwd
# Out:
# [Errno 2] No such file or directory: 'data'
# /Users/asamra/dev/DataEngineering.Labs.RegisteredVotersFileWilmingtonDE/data
# '/Users/asamra/dev/DataEngineering.Labs.RegisteredVotersFileWilmingtonDE/data'

# %% [markdown]
# Load the csv file into a Pandas DataFrame.

# %%
df = pd.read_csv('ActiveFile-Wilm1thru8-20191015.csv')
df
# Out:
#        UNIQUE-ID     LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH  \
# 0      100234840           ROY    BEVERLY        A    NaN           1952
# 1      100685572      WILLIAMS       LISA        F    NaN           1968
# 2      100485262        HARRIS     JOSEPH        A    III           1963
# 3      100349191       LAMBORN     GERALD        V    NaN           1958
# 4      100394887  KRYSTOPOLSKI     ANDREW        R    NaN           1981
# ...          ...           ...        ...      ...    ...            ...
# 51904  100876849       BROOMER  CHERLOTTE        D    NaN           1974
# 51905  100251665         HANEY     JANICE        M    NaN           1952
# 51906  101029340        MARTIN    ELMARIA        D    NaN           1966
# 51907  101145618          ROSE    KENISHA        A    NaN           1989
# 51908  100807909         ALLEN      SARAH        E    NaN           1987
#
#       HOME-NO HOME-APT    HOME-STREET            HOME-DEV  ... REF-HIST-5  \
# ...

# %% [markdown]
# Display a list of columns in the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51909 entries, 0 to 51908
# Data columns (total 54 columns):
# UNIQUE-ID         51909 non-null int64
# LAST-NAME         51909 non-null object
# FIRST-NAME        51909 non-null object
# MID-INIT          45309 non-null object
# SUFFIX            2936 non-null object
# YEAR-OF-BIRTH     51909 non-null int64
# HOME-NO           51909 non-null object
# HOME-APT          12560 non-null object
# HOME-STREET       51909 non-null object
# HOME-DEV          8794 non-null object
# HOME-CITY         51909 non-null object
# HOME-ZIPCODE      51909 non-null int64
# COUNTY            51909 non-null object
# ED                51909 non-null int64
# RD                51909 non-null int64
# SD                51909 non-null int64
# CNLEVY            51909 non-null int64
# WILM              51909 non-null int64
# CODE-HOME-CITY    4 non-null object
# SCH-DIST          51909 non-null object
# PARTY             51909 non-null object
# ...

# %% [markdown]
# What is the shape of this DataFrame? How many columns does each row have? How many rows are there?

# %%
df.shape
# Out:
# (51909, 54)

# %% [markdown]
# # HOME ZIP CODE

# %% [markdown]
# Group objects using the HOME-ZIPCODE column. Assign the value to a variable called grouped_zc.
# [Pandas Groupby User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)

# %%
grouped_zc = df.groupby('HOME-ZIPCODE')
grouped_zc

# %% [markdown]
# What type of object is grouped_zc?

# %%
# DataFrameGroupBy

# %% [markdown]
# DataFrameGroupBy objects contain a groups attribute. Display the value of the groups attribute belonging to the grouped_zc object.

# %%
grouped_zc.groups
# Out:
# {19801: Int64Index([    0,     1,    10,    12,    13,    15,    16,    20,    24,
#                 34,
#              ...
#              51865, 51874, 51877, 51881, 51885, 51890, 51891, 51892, 51897,
#              51900],
#             dtype='int64', length=10730),
#  19802: Int64Index([    3,     5,    11,    21,    29,    30,    31,    38,    39,
#                 40,
#              ...
#              51866, 51867, 51872, 51882, 51883, 51887, 51893, 51901, 51902,
#              51906],
#             dtype='int64', length=17182),
#  19805: Int64Index([    4,     6,     7,     8,    14,    17,    18,    19,    22,
#                 23,
#              ...
#              51862, 51864, 51869, 51873, 51880, 51886, 51888, 51889, 51898,
#              51904],
#             dtype='int64', length=15548),
#  19806: Int64Index([    2,     9,    28,    48,    83,    96,   106,   114,   150,
#                169,
#              ...
# ...

# %% [markdown]
# Invoke the size method on the grouped_zc object to find out how many items are associated with each zip code.

# %%
grouped_zc.size()
# Out:
# HOME-ZIPCODE
# 19801    10730
# 19802    17182
# 19805    15548
# 19806     8326
# 19807      123
# dtype: int64

# %%
# value_counts() also works
df['HOME-ZIPCODE'].value_counts()
# Out:
# 19802    17182
# 19805    15548
# 19801    10730
# 19806     8326
# 19807      123
# Name: HOME-ZIPCODE, dtype: int64

# %% [markdown]
# Use a magic command so that matplotlib graphics will display inline.

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':None}
# %matplotlib inline

# %% [markdown]
# Create a pie chart illustrating the number of voters per zip code.

# %%
voters = grouped_zc.size()
plt.pyplot.pie( voters, labels = ['19801','19802','19805', '19806','19807'] , explode = (0,0,0,0,.5) )
# Out:
# ([<matplotlib.patches.Wedge at 0x11c215a90>,
# ...
#  [Text(0.8760967626973386, 0.6651725057391077, '19801'),
#   Text(-0.764058752148303, 0.7913369846440758, '19802'),
#   Text(-0.42112865275664896, -1.0161942028113375, '19805'),
#   Text(0.9552631610472119, -0.5454102063090577, '19806'),
#   Text(1.5999556679781046, -0.011910520758435522, '19807')])

# %% [markdown]
# # YEAR OF BIRTH

# %% [markdown]
# Group objects by the YEAR-OF-BIRTH column. Assign the value to an object called "grouped_yob".

# %%
grouped_yob = df.groupby('YEAR-OF-BIRTH')
grouped_yob

# %% [markdown]
# Display the value of the groups attribute belonging the grouped_yob object.

# %%
grouped_yob.groups
# Out:
# {1900: Int64Index([49249], dtype='int64'),
#  1912: Int64Index([5607], dtype='int64'),
#  1915: Int64Index([6983, 7233], dtype='int64'),
#  1916: Int64Index([2773, 16265, 49808], dtype='int64'),
#  1917: Int64Index([2425, 12614], dtype='int64'),
#  1918: Int64Index([7276, 7318, 9601, 14196], dtype='int64'),
#  1919: Int64Index([12435, 17404, 22219, 23508, 42509], dtype='int64'),
#  1920: Int64Index([  271,   350,   534,  3468,  3541,  3909,  5485,  5606,  7071,
#              13684, 14831, 15495, 17447, 22093, 24793, 24934, 26266, 27799,
#              37052, 37182, 38014, 42055, 47857],
#             dtype='int64'),
#  1921: Int64Index([  977,  1048,  1905,  3326,  4066,  7893, 12729, 14907, 16396,
#              17176, 18116, 18736, 22236, 23100, 24936, 25142, 25335, 25632,
#              26505, 26592, 28858, 37963, 39804, 41209, 48463, 49695],
#             dtype='int64'),
#  1922: Int64Index([  159,  3071,  3299,  4044,  4159,  6558,  9461, 13850, 16113,
# ...

# %%
len(grouped_yob.groups)
# Out:
# 90

# %% [markdown]
# Select the object for the row indicating that the voter was born in 1900.

# %%
grouped_yob.get_group(1900)
# Out:
#        UNIQUE-ID LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH HOME-NO  \
# 49249  101092654   KENNEDY     JORDAN        D    NaN           1900     724
#
#       HOME-APT     HOME-STREET HOME-DEV  ... REF-HIST-5  MAIL-NO MAIL-APT  \
# 49249      NaN  N BANCROFT PKY      NaN  ...        NaN      NaN      NaN
#
#        MAIL-STR  MAIL-CITY  MAIL-STATE  MAIL-ZIP  DATE-LAST-CHG CODE-CHANGE  \
# 49249       NaN        NaN         NaN       NaN       20170731          P6
#
#       STATUS
# 49249      I
#
# [1 rows x 54 columns]

# %% [markdown]
# Graph a histogram to  illustrate the age distribution of voters in this dataset. Ty using different values for the bins attribute of the histogram.

# %%
#plt.pyplot.hist('YEAR-OF-BIRTH', bins=10)
df['YEAR-OF-BIRTH'].plot.hist(bins=10)

# %%
df['YEAR-OF-BIRTH'].plot.hist(bins=20)

# %% [markdown]
# # PARTY

# %% [markdown]
# Group objects using the PARTY column. Assign the value to a variable called grouped_p.

# %%
grouped_party = df.groupby('PARTY')
grouped_party

# %% [markdown]
# Display the value of the groups attribute belonging to the grouped_p object.

# %%
grouped_party.groups
# Out:
# {'A': Int64Index([ 2578,  2639,  3108,  5105, 10230, 10491, 10842, 11620, 12162,
#              12413, 12417, 12454, 12507, 12522, 12810, 12831, 14469, 14507,
#              15144, 15382, 15509, 16858, 17075, 17173, 17309, 19466, 19884,
#              20846, 21086, 21459, 22451, 22645, 22746, 23739, 24604, 24664,
#              24665, 24691, 26662, 28775, 30455, 30510, 30976, 34065, 34903,
#              36518, 44984, 45851, 46837, 49699, 51736, 51830],
#             dtype='int64'),
#  'B': Int64Index([11866, 11867, 11869, 11870, 11873, 11875, 11876, 11880, 11882,
#              11883,
#              ...
#              50153, 50167, 50172, 50176, 50211, 50246, 50339, 50340, 50343,
#              50469],
#             dtype='int64', length=441),
#  'D': Int64Index([    1,     3,     4,     5,     6,    10,    11,    12,    16,
#                 17,
#              ...
#              51896, 51897, 51898, 51899, 51901, 51902, 51904, 51905, 51906,
#              51907],
# ...

# %%
len(grouped_party)
# Out:
# 18

# %% [markdown]
# Invoke the size method on the grouped_p object to find out how many items are associated with each party.

# %%
size_party = grouped_party.size()
size_party
# Out:
# PARTY
# A       52
# B      441
# D    38020
# E       30
# G       42
# H       82
# I     7670
# J      161
# L       98
# M        1
# O       33
# Q       17
# R     4851
# T       14
# V       11
# W      333
# Y       14
# Z       39
# dtype: int64

# %% [markdown]
# Create a bar chart to visualize the number of voters associated with each party.

# %%
df['PARTY'].value_counts().plot(kind='bar', title = 'Party')

# %% [markdown]
# # Merging Two DataFrames

# %% [markdown]
# Using the data from the documentation, create a Pandas DataFrame that contains the party code and the corresponding legal name for each party.

# %%
df_party = pd.read_csv('PartyAffiliation.csv')
df_party
# Out:
#    Party Code                 Legal Name  Abbreviated Name   \
# 0          NaN                        NaN               NaN
# 1           A                   AMERICAN          AMERICAN
# 2          NaN                        NaN               NaN
# 3           B             AMERICAN DELTA        AMER DELTA
# 4          NaN                        NaN               NaN
# 5           D           DEMOCRATIC PARTY        DEMOCRATIC
# 6          NaN                        NaN               NaN
# 7           E                    LIBERAL           LIBERAL
# 8          NaN                        NaN               NaN
# 9           G               NON PARTISAN        N PARTISAN
# 10         NaN                        NaN               NaN
# 11          H                GREEN PARTY             GREEN
# 12         NaN                        NaN               NaN
# 13          I               UNAFFILIATED        UNAFFILIAT
# 14         NaN                        NaN               NaN
# ...

# %%
df_party = df_party.dropna(how = 'all')
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
df_party
# Out:
#    Party Code                 Legal Name  Abbreviated Name   \
# 1           A                   AMERICAN          AMERICAN
# 3           B             AMERICAN DELTA        AMER DELTA
# 5           D           DEMOCRATIC PARTY        DEMOCRATIC
# 7           E                    LIBERAL           LIBERAL
# 9           G               NON PARTISAN        N PARTISAN
# 11          H                GREEN PARTY             GREEN
# 13          I               UNAFFILIATED        UNAFFILIAT
# 15          J     WORKING FAMILIES PARTY               WFP
# 17          L          LIBERTARIAN PARTY        LIBERTARIN
# 19          M               REFORM PARTY            REFORM
# 21          O   OTHERS/ALL OTHER PARTIES            OTHERS
# 23          Q         CONSTITUTION PARTY        CONSTITUTN
# 25          R           REPUBLICAN PARTY        REPUBLICAN
# 27          T               CONSERVATIVE        CONSERVATI
# 29          V          NATURAL LAW PARTY        NATURAL LW
# ...

# %%
df_party = df_party.reset_index()
df_party
# Out:
#     index Party Code                 Legal Name  Abbreviated Name   \
# 0       1          A                   AMERICAN          AMERICAN
# 1       3          B             AMERICAN DELTA        AMER DELTA
# 2       5          D           DEMOCRATIC PARTY        DEMOCRATIC
# 3       7          E                    LIBERAL           LIBERAL
# 4       9          G               NON PARTISAN        N PARTISAN
# 5      11          H                GREEN PARTY             GREEN
# 6      13          I               UNAFFILIATED        UNAFFILIAT
# 7      15          J     WORKING FAMILIES PARTY               WFP
# 8      17          L          LIBERTARIAN PARTY        LIBERTARIN
# 9      19          M               REFORM PARTY            REFORM
# 10     21          O   OTHERS/ALL OTHER PARTIES            OTHERS
# 11     23          Q         CONSTITUTION PARTY        CONSTITUTN
# 12     25          R           REPUBLICAN PARTY        REPUBLICAN
# ...

# %%
df_party = df_party.drop(['index'], axis = 1)
df_party
# Out:
#    Party Code                 Legal Name  Abbreviated Name   \
# 0           A                   AMERICAN          AMERICAN
# 1           B             AMERICAN DELTA        AMER DELTA
# 2           D           DEMOCRATIC PARTY        DEMOCRATIC
# 3           E                    LIBERAL           LIBERAL
# 4           G               NON PARTISAN        N PARTISAN
# 5           H                GREEN PARTY             GREEN
# 6           I               UNAFFILIATED        UNAFFILIAT
# 7           J     WORKING FAMILIES PARTY               WFP
# 8           L          LIBERTARIAN PARTY        LIBERTARIN
# 9           M               REFORM PARTY            REFORM
# 10          O   OTHERS/ALL OTHER PARTIES            OTHERS
# 11          Q         CONSTITUTION PARTY        CONSTITUTN
# 12          R           REPUBLICAN PARTY        REPUBLICAN
# 13          T               CONSERVATIVE        CONSERVATI
# 14          V          NATURAL LAW PARTY        NATURAL LW
# ...

# %%
df_party = df_party.dropna(axis = 'columns')
df_party
# Out:
#    Party Code                 Legal Name  Abbreviated Name
# 0           A                   AMERICAN          AMERICAN
# 1           B             AMERICAN DELTA        AMER DELTA
# 2           D           DEMOCRATIC PARTY        DEMOCRATIC
# 3           E                    LIBERAL           LIBERAL
# 4           G               NON PARTISAN        N PARTISAN
# 5           H                GREEN PARTY             GREEN
# 6           I               UNAFFILIATED        UNAFFILIAT
# 7           J     WORKING FAMILIES PARTY               WFP
# 8           L          LIBERTARIAN PARTY        LIBERTARIN
# 9           M               REFORM PARTY            REFORM
# 10          O   OTHERS/ALL OTHER PARTIES            OTHERS
# 11          Q         CONSTITUTION PARTY        CONSTITUTN
# 12          R           REPUBLICAN PARTY        REPUBLICAN
# 13          T               CONSERVATIVE        CONSERVATI
# 14          V          NATURAL LAW PARTY        NATURAL LW
# ...

# %%
# legal_names = {}

# %%
# df_legal_names = pd.DataFrame(legal_names)

# %%
df_legal_names = df_party
df_legal_names
# Out:
#    Party Code                 Legal Name  Abbreviated Name
# 0           A                   AMERICAN          AMERICAN
# 1           B             AMERICAN DELTA        AMER DELTA
# 2           D           DEMOCRATIC PARTY        DEMOCRATIC
# 3           E                    LIBERAL           LIBERAL
# 4           G               NON PARTISAN        N PARTISAN
# 5           H                GREEN PARTY             GREEN
# 6           I               UNAFFILIATED        UNAFFILIAT
# 7           J     WORKING FAMILIES PARTY               WFP
# 8           L          LIBERTARIAN PARTY        LIBERTARIN
# 9           M               REFORM PARTY            REFORM
# 10          O   OTHERS/ALL OTHER PARTIES            OTHERS
# 11          Q         CONSTITUTION PARTY        CONSTITUTN
# 12          R           REPUBLICAN PARTY        REPUBLICAN
# 13          T               CONSERVATIVE        CONSERVATI
# 14          V          NATURAL LAW PARTY        NATURAL LW
# ...

# %% [markdown]
# Create a Pandas DataFrame that contains the Party code and the corresponding number of registered voters for said party.

# %%
# Create DataFrame df_party_counts here
df_party_counts = pd.DataFrame(size_party)
df_party_counts
# Out:
#            0
# PARTY
# A         52
# B        441
# D      38020
# E         30
# G         42
# H         82
# I       7670
# J        161
# L         98
# M          1
# O         33
# Q         17
# R       4851
# T         14
# V         11
# W        333
# Y         14
# Z         39

# %%
df_party_counts = df_party_counts.rename(columns={0: "PARTY COUNTS"})

# %%
# df_party_counts
df_party_counts
# Out:
#        PARTY COUNTS
# PARTY
# A                52
# B               441
# D             38020
# E                30
# G                42
# H                82
# I              7670
# J               161
# L                98
# M                 1
# O                33
# Q                17
# R              4851
# T                14
# V                11
# W               333
# Y                14
# Z                39

# %% [markdown]
# Merge the two DataFrames.

# %%
df_legal_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
# Party Code           18 non-null object
# Legal Name           18 non-null object
# Abbreviated Name     18 non-null object
# dtypes: object(3)
# memory usage: 560.0+ bytes

# %%
df_party_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, A to Z
# Data columns (total 1 columns):
# PARTY COUNTS    18 non-null int64
# dtypes: int64(1)
# memory usage: 288.0+ bytes

# %%
# Merge DataFrame here
#df_merged = df_legal_names(df_party_counts, left_on='Party Code', right_on='PARTY')
df_merged = pd.concat([df_legal_names, df_party_counts], sort=True)

# %%
# Display new DataFrame here 
df_merged
# Out:
#    Abbreviated Name                 Legal Name   PARTY COUNTS Party Code
# 0          AMERICAN                   AMERICAN            NaN          A
# 1        AMER DELTA             AMERICAN DELTA            NaN          B
# 2        DEMOCRATIC           DEMOCRATIC PARTY            NaN          D
# 3           LIBERAL                    LIBERAL            NaN          E
# 4        N PARTISAN               NON PARTISAN            NaN          G
# 5             GREEN                GREEN PARTY            NaN          H
# 6        UNAFFILIAT               UNAFFILIATED            NaN          I
# 7               WFP     WORKING FAMILIES PARTY            NaN          J
# 8        LIBERTARIN          LIBERTARIAN PARTY            NaN          L
# 9            REFORM               REFORM PARTY            NaN          M
# 10           OTHERS   OTHERS/ALL OTHER PARTIES            NaN          O
# 11       CONSTITUTN         CONSTITUTION PARTY            NaN          Q
# ...

# %% [markdown]
# Create a bar graph again but using the legal name for each party as the value on the x axes.

# %%
#
